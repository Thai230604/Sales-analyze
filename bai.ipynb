# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='latin1')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2 2871.00
# 1        10121               34      81.35                5 2765.90
# 2        10134               41      94.74                2 3884.34
# 3        10145               45      83.26                6 3746.70
# 4        10159               49     100.00               14 5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
for column in df.columns:
    print(column ,  "------------------",df[column].dtype, "-------------------",df[column].isnull().sum())
# Out:
# ORDERNUMBER ------------------ int64 ------------------- 0
# QUANTITYORDERED ------------------ int64 ------------------- 0
# PRICEEACH ------------------ float64 ------------------- 0
# ORDERLINENUMBER ------------------ int64 ------------------- 0
# SALES ------------------ float64 ------------------- 0
# ORDERDATE ------------------ object ------------------- 0
# STATUS ------------------ object ------------------- 0
# QTR_ID ------------------ int64 ------------------- 0
# MONTH_ID ------------------ int64 ------------------- 0
# YEAR_ID ------------------ int64 ------------------- 0
# PRODUCTLINE ------------------ object ------------------- 0
# MSRP ------------------ int64 ------------------- 0
# PRODUCTCODE ------------------ object ------------------- 0
# CUSTOMERNAME ------------------ object ------------------- 0
# PHONE ------------------ object ------------------- 0
# ADDRESSLINE1 ------------------ object ------------------- 0
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2 2871.00
# 1        10121               34      81.35                5 2765.90
# 2        10134               41      94.74                2 3884.34
# 3        10145               45      83.26                6 3746.70
# 4        10159               49     100.00               14 5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.describe()
# Out:
#        ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# count      2823.00          2823.00    2823.00          2823.00  2823.00
# mean      10258.73            35.09      83.66             6.47  3553.89
# std          92.09             9.74      20.17             4.23  1841.87
# min       10100.00             6.00      26.88             1.00   482.13
# 25%       10180.00            27.00      68.86             3.00  2203.43
# 50%       10262.00            35.00      95.70             6.00  3184.80
# 75%       10333.50            43.00     100.00             9.00  4508.00
# max       10425.00            97.00     100.00            18.00 14082.80
#
#        QTR_ID  MONTH_ID  YEAR_ID    MSRP
# count 2823.00   2823.00  2823.00 2823.00
# mean     2.72      7.09  2003.82  100.72
# std      1.20      3.66     0.70   40.19
# min      1.00      1.00  2003.00   33.00
# 25%      2.00      4.00  2003.00   68.00
# 50%      3.00      8.00  2004.00   99.00
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
l = ['ADDRESSLINE1', 'ADDRESSLINE2', 'STATE', 'POSTALCODE', 'TERRITORY']
df[l] = imputer.fit_transform(df[l])

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
for column in df.columns:
    if df[column].dtype != 'object':
        sns.boxplot(df[column])
        plt.show()

        q1 = df[column].quantile(0.25)
        q3 = df[column].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        df= df[(df[column] < upper_bound) & (df[column] > lower_bound)]
        sns.boxplot(df[column])
        plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2691 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2691 non-null   int64
#  1   QUANTITYORDERED   2691 non-null   int64
#  2   PRICEEACH         2691 non-null   float64
#  3   ORDERLINENUMBER   2691 non-null   int64
#  4   SALES             2691 non-null   float64
#  5   ORDERDATE         2691 non-null   object
#  6   STATUS            2691 non-null   object
#  7   QTR_ID            2691 non-null   int64
#  8   MONTH_ID          2691 non-null   int64
#  9   YEAR_ID           2691 non-null   int64
#  10  PRODUCTLINE       2691 non-null   object
#  11  MSRP              2691 non-null   int64
#  12  PRODUCTCODE       2691 non-null   object
#  13  CUSTOMERNAME      2691 non-null   object
#  14  PHONE             2691 non-null   object
#  15  ADDRESSLINE1      2691 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(df[column].unique())
# Out:
# ['2/24/2003 0:00' '5/7/2003 0:00' '7/1/2003 0:00' '8/25/2003 0:00'
#  '10/10/2003 0:00' '10/28/2003 0:00' '11/11/2003 0:00' '11/18/2003 0:00'
#  '12/1/2003 0:00' '1/15/2004 0:00' '2/20/2004 0:00' '4/5/2004 0:00'
#  '5/18/2004 0:00' '6/28/2004 0:00' '7/23/2004 0:00' '8/27/2004 0:00'
#  '9/30/2004 0:00' '10/15/2004 0:00' '11/2/2004 0:00' '11/15/2004 0:00'
#  '11/24/2004 0:00' '12/17/2004 0:00' '2/3/2005 0:00' '3/3/2005 0:00'
#  '4/8/2005 0:00' '5/13/2005 0:00' '4/29/2003 0:00' '1/12/2004 0:00'
#  '4/3/2004 0:00' '9/27/2004 0:00' '11/23/2004 0:00' '2/2/2005 0:00'
#  '4/7/2005 0:00' '1/5/2005 0:00' '2/11/2003 0:00' '4/28/2003 0:00'
#  '6/12/2003 0:00' '8/10/2003 0:00' '10/6/2003 0:00' '10/23/2003 0:00'
#  '11/8/2003 0:00' '11/14/2003 0:00' '11/26/2003 0:00' '1/9/2004 0:00'
#  '2/19/2004 0:00' '5/7/2004 0:00' '6/17/2004 0:00' '7/21/2004 0:00'
#  '8/20/2004 0:00' '9/10/2004 0:00' '10/14/2004 0:00' '11/1/2004 0:00'
#  '11/5/2004 0:00' '11/21/2004 0:00' '12/2/2004 0:00' '12/15/2004 0:00'
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df['SALES']
# Out:
# 0      2871.00
# 1      2765.90
# 2      3884.34
# 3      3746.70
# 4      5205.27
#          ...
# 2818   2244.40
# 2819   3978.51
# 2820   5417.57
# 2821   2116.16
# 2822   3079.44
# Name: SALES, Length: 2691, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2691 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2691 non-null   int64
#  1   QUANTITYORDERED   2691 non-null   int64
#  2   PRICEEACH         2691 non-null   float64
#  3   ORDERLINENUMBER   2691 non-null   int64
#  4   SALES             2691 non-null   float64
#  5   ORDERDATE         2691 non-null   object
#  6   STATUS            2691 non-null   object
#  7   QTR_ID            2691 non-null   int64
#  8   MONTH_ID          2691 non-null   int64
#  9   YEAR_ID           2691 non-null   int64
#  10  PRODUCTLINE       2691 non-null   object
#  11  MSRP              2691 non-null   int64
#  12  PRODUCTCODE       2691 non-null   object
#  13  CUSTOMERNAME      2691 non-null   object
#  14  PHONE             2691 non-null   object
#  15  ADDRESSLINE1      2691 non-null   object
# ...

# %%
features = ['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'PRODUCTLINE', 'MSRP', 'DEALSIZE', 'TERRITORY', 'MONTH_ID', 'QTR_ID', 'YEAR_ID']
df[features].head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  PRODUCTLINE  MSRP DEALSIZE  \
# 0               30      95.70                2  Motorcycles    95    Small
# 1               34      81.35                5  Motorcycles    95    Small
# 2               41      94.74                2  Motorcycles    95   Medium
# 3               45      83.26                6  Motorcycles    95   Medium
# 4               49     100.00               14  Motorcycles    95   Medium
#
#   TERRITORY  MONTH_ID  QTR_ID  YEAR_ID
# 0      EMEA         2       1     2003
# 1      EMEA         5       2     2003
# 2      EMEA         7       3     2003
# 3      EMEA         8       3     2003
# 4      EMEA        10       4     2003

# %%
df['DEALSIZE'].unique()
# Out:
# array(['Small', 'Medium', 'Large'], dtype=object)

# %%
num_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])
sizes = ['Small', 'Medium', 'Large']
ord_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(categories=[sizes]))
])
nom_transform = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder())
])

# %%
preprocessor = ColumnTransformer([
    ('num', num_transform, ['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'MSRP', 'MONTH_ID', 'QTR_ID', 'YEAR_ID']),
    ('ord', ord_transform, ['DEALSIZE']),
    ('nom', nom_transform, ['PRODUCTLINE', 'TERRITORY'])
])

# %%
df[features].head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  PRODUCTLINE  MSRP DEALSIZE  \
# 0               30      95.70                2  Motorcycles    95    Small
# 1               34      81.35                5  Motorcycles    95    Small
# 2               41      94.74                2  Motorcycles    95   Medium
# 3               45      83.26                6  Motorcycles    95   Medium
# 4               49     100.00               14  Motorcycles    95   Medium
#
#   TERRITORY  MONTH_ID  QTR_ID  YEAR_ID
# 0      EMEA         2       1     2003
# 1      EMEA         5       2     2003
# 2      EMEA         7       3     2003
# 3      EMEA         8       3     2003
# 4      EMEA        10       4     2003

# %%
new_df = df[features]
new_df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  PRODUCTLINE  MSRP DEALSIZE  \
# 0               30      95.70                2  Motorcycles    95    Small
# 1               34      81.35                5  Motorcycles    95    Small
# 2               41      94.74                2  Motorcycles    95   Medium
# 3               45      83.26                6  Motorcycles    95   Medium
# 4               49     100.00               14  Motorcycles    95   Medium
#
#   TERRITORY  MONTH_ID  QTR_ID  YEAR_ID
# 0      EMEA         2       1     2003
# 1      EMEA         5       2     2003
# 2      EMEA         7       3     2003
# 3      EMEA         8       3     2003
# 4      EMEA        10       4     2003

# %%
sizes = ['Small', 'Medium', 'Large']
new_df['DEALSIZE'] = OrdinalEncoder(categories=[sizes]).fit_transform(new_df[['DEALSIZE']])

# %%
new_df
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  PRODUCTLINE  MSRP  \
# 0                  30      95.70                2  Motorcycles    95
# 1                  34      81.35                5  Motorcycles    95
# 2                  41      94.74                2  Motorcycles    95
# 3                  45      83.26                6  Motorcycles    95
# 4                  49     100.00               14  Motorcycles    95
# ...               ...        ...              ...          ...   ...
# 2818               20     100.00               15        Ships    54
# 2819               29     100.00                1        Ships    54
# 2820               43     100.00                4        Ships    54
# 2821               34      62.24                1        Ships    54
# 2822               47      65.52                9        Ships    54
#
#       DEALSIZE TERRITORY  MONTH_ID  QTR_ID  YEAR_ID
# 0         0.00      EMEA         2       1     2003
# ...

# %%
new_df = pd.get_dummies(new_df, columns=['PRODUCTLINE', 'TERRITORY'], drop_first=True)

# %%
new_df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  MSRP  DEALSIZE  MONTH_ID  \
# 0               30      95.70                2    95      0.00         2
# 1               34      81.35                5    95      0.00         5
# 2               41      94.74                2    95      1.00         7
# 3               45      83.26                6    95      1.00         8
# 4               49     100.00               14    95      1.00        10
#
#    QTR_ID  YEAR_ID  PRODUCTLINE_Motorcycles  PRODUCTLINE_Planes  \
# 0       1     2003                     True               False
# 1       2     2003                     True               False
# 2       3     2003                     True               False
# 3       3     2003                     True               False
# 4       4     2003                     True               False
#
#    PRODUCTLINE_Ships  PRODUCTLINE_Trains  PRODUCTLINE_Trucks and Buses  \
# ...

# %%
# Install lazypredict package
# %pip install lazypredict

from lazypredict.Supervised import LazyRegressor
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
features
# Out:
# ['QUANTITYORDERED',
#  'PRICEEACH',
#  'ORDERLINENUMBER',
#  'PRODUCTLINE',
#  'MSRP',
#  'DEALSIZE',
#  'TERRITORY',
#  'MONTH_ID',
#  'QTR_ID',
#  'YEAR_ID']

# %%
df['SALES']
# Out:
# 0      2871.00
# 1      2765.90
# 2      3884.34
# 3      3746.70
# 4      5205.27
#          ...
# 2818   2244.40
# 2819   3978.51
# 2820   5417.57
# 2821   2116.16
# 2822   3079.44
# Name: SALES, Length: 2691, dtype: float64

# %%
x = new_df
y = df['SALES']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(x_train, x_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:04<00:00, 10.43it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000097 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 2152, number of used features: 8
# [LightGBM] [Info] Start training from score 3362.361779
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# RandomForestRegressor                        0.96       0.96  325.51
# HistGradientBoostingRegressor                0.96       0.96  329.44
# ExtraTreesRegressor                          0.95       0.96  333.12
# LGBMRegressor                                0.95       0.96  334.46
# GradientBoostingRegressor                    0.95       0.95  342.59
# BaggingRegressor                             0.95       0.95  347.39
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
lgbm = GradientBoostingRegressor()
lgbm.fit(x_train, y_train)
y_pred = lgbm.predict(x_test)
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(y_test, y_pred)
r2_score(y_test, y_pred)
# Out:
# 0.9529930741599327

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
y_pred = lin_reg.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from sklearn.linear_model import LinearRegression, SVR
#       2 lin_reg = LinearRegression()
#       3 lin_reg.fit(x_train, y_train)
#
# ImportError: cannot import name 'SVR' from 'sklearn.linear_model' (c:\Users\Admin\Documents\Python\T01\.venv\Lib\site-packages\sklearn\linear_model\__init__.py)

# %%
from sklearn.svm import SVR
svc = SVR()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# -0.014730558147325379
